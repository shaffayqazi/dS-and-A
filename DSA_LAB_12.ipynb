# %% [markdown]
# <a href="https://colab.research.google.com/github/shaffayqazi/dS-and-A/blob/main/DSA_LAB_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# Fetch a web page
r = requests.get("https://medium.com/p/ef1e92faa535")
print(r.text)
# Out:
# <!doctype html><html lang="en"><head><title data-rh="true">Predicting Telecom Customer Churn Using Data Science | by Abdul Shaffay Qazi | Oct, 2023 | Medium</title><meta data-rh="true" charset="utf-8"/><meta data-rh="true" name="viewport" content="width=device-width,minimum-scale=1,initial-scale=1,maximum-scale=1"/><meta data-rh="true" name="theme-color" content="#000000"/><meta data-rh="true" name="twitter:app:name:iphone" content="Medium"/><meta data-rh="true" name="twitter:app:id:iphone" content="828256236"/><meta data-rh="true" property="al:ios:app_name" content="Medium"/><meta data-rh="true" property="al:ios:app_store_id" content="828256236"/><meta data-rh="true" property="al:android:package" content="com.medium.reader"/><meta data-rh="true" property="fb:app_id" content="542599432471018"/><meta data-rh="true" property="og:site_name" content="Medium"/><meta data-rh="true" property="og:type" content="article"/><meta data-rh="true" property="article:published_time" content="2023-10
# ...

# %%
import re

# Remove HTML tags using RegularExpression
pattern = re.compile(r'<.*?>')  # tags look like <...>
print(pattern.sub('', r.text))  # replace them with blank
# Out:
# Predicting Telecom Customer Churn Using Data Science | by Abdul Shaffay Qazi | Oct, 2023 | Medium{"@context":"http:\u002F\u002Fschema.org","@type":"NewsArticle","image":["https:\u002F\u002Fmiro.medium.com\u002Fv2\u002Fresize:fit:1200\u002F1*KZ3hyCd6X3dRkE5Ree5Lmw.png"],"url":"https:\u002F\u002Fmedium.com\u002F@abdulshaffayqazi\u002Fpredicting-telecom-customer-churn-using-data-science-ef1e92faa535","dateCreated":"2023-10-09T04:06:13.552Z","datePublished":"2023-10-09T04:06:13.552Z","dateModified":"2023-10-09T06:14:05.383Z","headline":"Predicting Telecom Customer Churn Using Data Science","name":"Predicting Telecom Customer Churn Using Data Science","description":"In the ever-evolving landscape of the telecommunications industry, customer churn represents a formidable challenge. For telecom companies, retaining customers is not just a financial imperative but…","identifier":"ef1e92faa535","author":{"@type":"Person","name":"Abdul Shaffay Qazi","url":"https:\u002F\u002Fmedium.com\u002F@ab
# ...

# %%
from bs4 import BeautifulSoup

# %%
# Remove HTML tags using Beautiful Soup library
soup = BeautifulSoup(r.text, "html5lib")
print(soup.get_text())
# Out:
# Predicting Telecom Customer Churn Using Data Science | by Abdul Shaffay Qazi | Oct, 2023 | Medium{"@context":"http:\u002F\u002Fschema.org","@type":"NewsArticle","image":["https:\u002F\u002Fmiro.medium.com\u002Fv2\u002Fresize:fit:1200\u002F1*KZ3hyCd6X3dRkE5Ree5Lmw.png"],"url":"https:\u002F\u002Fmedium.com\u002F@abdulshaffayqazi\u002Fpredicting-telecom-customer-churn-using-data-science-ef1e92faa535","dateCreated":"2023-10-09T04:06:13.552Z","datePublished":"2023-10-09T04:06:13.552Z","dateModified":"2023-10-09T06:14:05.383Z","headline":"Predicting Telecom Customer Churn Using Data Science","name":"Predicting Telecom Customer Churn Using Data Science","description":"In the ever-evolving landscape of the telecommunications industry, customer churn represents a formidable challenge. For telecom companies, retaining customers is not just a financial imperative but…","identifier":"ef1e92faa535","author":{"@type":"Person","name":"Abdul Shaffay Qazi","url":"https:\u002F\u002Fmedium.com\u002F@ab
# ...

# %%
#mw-content-container
# Find all articles
summaries = soup.find_all("div", class_="l")
summaries[0]
# Out:
# <div class="l c"><div class="l m n o c"><div class="p q r s t u v w x i d y z"></div><div class="p q r ab ac"><div class="ab q ae"><a aria-label="Homepage" class="af ag ah ai aj ak al am an ao ap aq ar as at ab" data-testid="headerMediumLogo" href="/?source=---two_column_layout_nav----------------------------------" rel="noopener follow"><svg class="au av" viewBox="0 0 1043.63 592.71"><g data-name="Layer 2"><g data-name="Layer 1"><path d="M588.67 296.36c0 163.67-131.78 296.35-294.33 296.35S0 460 0 296.36 131.78 0 294.34 0s294.33 132.69 294.33 296.36M911.56 296.36c0 154.06-65.89 279-147.17 279s-147.17-124.94-147.17-279 65.88-279 147.16-279 147.17 124.9 147.17 279M1043.63 296.36c0 138-23.17 249.94-51.76 249.94s-51.75-111.91-51.75-249.94 23.17-249.94 51.75-249.94 51.76 111.9 51.76 249.94"></path></g></g></svg></a><div class="aw h"><div class="ab ax ay az ba q bb bc"><div aria-describedby="searchResults" aria-hidden="false" aria-labelledby="searchResults" class="bl"></div><div class="bm 
# ...

# %%
scraped_data = summaries[0].get_text().strip()

# %%
scraped_data= scraped_data.lower()

# %%
import re

# Remove punctuation characters
scraped_data = re.sub(r"[^a-zA-Z0-9]", " ", scraped_data)
print(scraped_data)
# Out:
# predicting telecom customer churn using data scienceabdul shaffay qazi follow4 min read 2 hours ago  listenshareintroductionin the ever evolving landscape of the telecommunications industry  customer churn represents a formidable challenge  for telecom companies  retaining customers is not just a financial imperative but a key to sustaining growth and competitiveness  enter data science   the powerful tool that can provide insights  predict churn  and guide strategic decisions in this step by step tutorial  we embark on a journey through the world of data science to tackle the issue of telecom customer churn prediction  whether you re a seasoned data scientist or someone with a budding interest in the field  this blog aims to be your compass we have four business questions that we are going to address1  is there a significant difference in the distribution of churn categories between male and female customers 2  among customers who are currently using the service  do those from certa
# ...

# %%
# Split text into tokens (words)
words = scraped_data.split()
print(words)
# Out:
# ['predicting', 'telecom', 'customer', 'churn', 'using', 'data', 'scienceabdul', 'shaffay', 'qazi', 'follow4', 'min', 'read', '2', 'hours', 'ago', 'listenshareintroductionin', 'the', 'ever', 'evolving', 'landscape', 'of', 'the', 'telecommunications', 'industry', 'customer', 'churn', 'represents', 'a', 'formidable', 'challenge', 'for', 'telecom', 'companies', 'retaining', 'customers', 'is', 'not', 'just', 'a', 'financial', 'imperative', 'but', 'a', 'key', 'to', 'sustaining', 'growth', 'and', 'competitiveness', 'enter', 'data', 'science', 'the', 'powerful', 'tool', 'that', 'can', 'provide', 'insights', 'predict', 'churn', 'and', 'guide', 'strategic', 'decisions', 'in', 'this', 'step', 'by', 'step', 'tutorial', 'we', 'embark', 'on', 'a', 'journey', 'through', 'the', 'world', 'of', 'data', 'science', 'to', 'tackle', 'the', 'issue', 'of', 'telecom', 'customer', 'churn', 'prediction', 'whether', 'you', 're', 'a', 'seasoned', 'data', 'scientist', 'or', 'someone', 'with', 'a', 'budding', 'int
# ...

# %%
import os
import nltk
nltk.data.path.append(os.path.join(os.getcwd(), "nltk_data"))

# %%
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')

# Split text into words using NLTK
words = word_tokenize(scraped_data)
print(words)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ...

# %%
from nltk.tokenize import sent_tokenize

# Split text into sentences
sentences = sent_tokenize(scraped_data)
print(sentences)
# Out:
# ['predicting telecom customer churn using data scienceabdul shaffay qazi follow4 min read 2 hours ago  listenshareintroductionin the ever evolving landscape of the telecommunications industry  customer churn represents a formidable challenge  for telecom companies  retaining customers is not just a financial imperative but a key to sustaining growth and competitiveness  enter data science   the powerful tool that can provide insights  predict churn  and guide strategic decisions in this step by step tutorial  we embark on a journey through the world of data science to tackle the issue of telecom customer churn prediction  whether you re a seasoned data scientist or someone with a budding interest in the field  this blog aims to be your compass we have four business questions that we are going to address1  is there a significant difference in the distribution of churn categories between male and female customers 2  among customers who are currently using the service  do those from cer
# ...

# %%
# List stop words
from nltk.corpus import stopwords
nltk.download('stopwords')
print(stopwords.words("english"))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
# Remove stop words
words = [w for w in words if w not in stopwords.words("english")]
print(words)
# Out:
# ['predicting', 'telecom', 'customer', 'churn', 'using', 'data', 'scienceabdul', 'shaffay', 'qazi', 'follow4', 'min', 'read', '2', 'hours', 'ago', 'listenshareintroductionin', 'ever', 'evolving', 'landscape', 'telecommunications', 'industry', 'customer', 'churn', 'represents', 'formidable', 'challenge', 'telecom', 'companies', 'retaining', 'customers', 'financial', 'imperative', 'key', 'sustaining', 'growth', 'competitiveness', 'enter', 'data', 'science', 'powerful', 'tool', 'provide', 'insights', 'predict', 'churn', 'guide', 'strategic', 'decisions', 'step', 'step', 'tutorial', 'embark', 'journey', 'world', 'data', 'science', 'tackle', 'issue', 'telecom', 'customer', 'churn', 'prediction', 'whether', 'seasoned', 'data', 'scientist', 'someone', 'budding', 'interest', 'field', 'blog', 'aims', 'compass', 'four', 'business', 'questions', 'going', 'address1', 'significant', 'difference', 'distribution', 'churn', 'categories', 'male', 'female', 'customers', '2', 'among', 'customers', 'curr
# ...

# %%
import nltk

# Define a custom grammar
my_grammar = nltk.CFG.fromstring("""
S -> NP VP
PP -> P NP
NP -> Det N | Det N PP | 'I'
VP -> V NP | VP PP
Det -> 'an' | 'my'
N -> 'elephant' | 'pajamas'
V -> 'shot'
P -> 'in'
""")
parser = nltk.ChartParser(my_grammar)

# Parse a sentence
sentence = word_tokenize("I shot an elephant in my pajamas")
for tree in parser.parse(sentence):
    print(tree)
# Out:
# (S
#   (NP I)
#   (VP
#     (VP (V shot) (NP (Det an) (N elephant)))
#     (PP (P in) (NP (Det my) (N pajamas)))))
# (S
#   (NP I)
#   (VP
#     (V shot)
#     (NP (Det an) (N elephant) (PP (P in) (NP (Det my) (N pajamas))))))

# %%
from nltk.stem.porter import PorterStemmer

# Reduce words to their stems
stemmed = [PorterStemmer().stem(w) for w in words]
print(stemmed)
# Out:
# ['predict', 'telecom', 'custom', 'churn', 'use', 'data', 'scienceabdul', 'shaffay', 'qazi', 'follow4', 'min', 'read', '2', 'hour', 'ago', 'listenshareintroductionin', 'ever', 'evolv', 'landscap', 'telecommun', 'industri', 'custom', 'churn', 'repres', 'formid', 'challeng', 'telecom', 'compani', 'retain', 'custom', 'financi', 'imper', 'key', 'sustain', 'growth', 'competit', 'enter', 'data', 'scienc', 'power', 'tool', 'provid', 'insight', 'predict', 'churn', 'guid', 'strateg', 'decis', 'step', 'step', 'tutori', 'embark', 'journey', 'world', 'data', 'scienc', 'tackl', 'issu', 'telecom', 'custom', 'churn', 'predict', 'whether', 'season', 'data', 'scientist', 'someon', 'bud', 'interest', 'field', 'blog', 'aim', 'compass', 'four', 'busi', 'question', 'go', 'address1', 'signific', 'differ', 'distribut', 'churn', 'categori', 'male', 'femal', 'custom', '2', 'among', 'custom', 'current', 'use', 'servic', 'certain', 'citi', '3', 'distribut', 'custom', 'gender', 'age', 'marit', 'statu', 'understa
# ...

# %%
from nltk.stem.wordnet import WordNetLemmatizer
nltk.download('wordnet')
# Reduce words to their root form
lemmed = [WordNetLemmatizer().lemmatize(w) for w in words]
print(lemmed)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# ...

# %%
# Lemmatize verbs by specifying pos
lemmed = [WordNetLemmatizer().lemmatize(w, pos='v') for w in lemmed]
print(lemmed)
# Out:
# ['predict', 'telecom', 'customer', 'churn', 'use', 'data', 'scienceabdul', 'shaffay', 'qazi', 'follow4', 'min', 'read', '2', 'hour', 'ago', 'listenshareintroductionin', 'ever', 'evolve', 'landscape', 'telecommunication', 'industry', 'customer', 'churn', 'represent', 'formidable', 'challenge', 'telecom', 'company', 'retain', 'customer', 'financial', 'imperative', 'key', 'sustain', 'growth', 'competitiveness', 'enter', 'data', 'science', 'powerful', 'tool', 'provide', 'insight', 'predict', 'churn', 'guide', 'strategic', 'decision', 'step', 'step', 'tutorial', 'embark', 'journey', 'world', 'data', 'science', 'tackle', 'issue', 'telecom', 'customer', 'churn', 'prediction', 'whether', 'season', 'data', 'scientist', 'someone', 'bud', 'interest', 'field', 'blog', 'aim', 'compass', 'four', 'business', 'question', 'go', 'address1', 'significant', 'difference', 'distribution', 'churn', 'category', 'male', 'female', 'customer', '2', 'among', 'customer', 'currently', 'use', 'service', 'certain',
# ...
